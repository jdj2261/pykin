# %% [markdown]
# # Robot Info
#
# First, you need to install Pykin (see installations instructions). You also need a URDF file.
#
# By default, we use the files provided in the asset/urdf directory of the Pykin repo.
#
# If this directory is empty, you need to go to https://github.com/jdj2261/urdf.git and download the robot's urdf file.

# %% [markdown]
# Import the Pykin module

# %%
file_path = '../asset/urdf/baxter/baxter.urdf'

# baxter, panda, sawyer, iiwa7, iiwa14, ur5e
robot_name = "baxter"
file_path = '../asset/urdf/' + robot_name + '/' + robot_name + '.urdf'

# %%
if "baxter" in file_path:
    from pykin.robots.bimanual import Bimanual
    robot = Bimanual(file_path)
else:
    from pykin.robots.single_arm import SingleArm
    robot = SingleArm(file_path)

robot.show_robot_info()
# Out:
# ****************************************************************************************************
# Robot Information:
#
#         Link( name= base
#             offset= Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.])
#             visual= Visual(offset=Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.]),
#                            geom_type=None,
#                            geom_param=None)
#             collision= Collision(offset=Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.]),
#                               geom_type=None,
#                               geom_param=None)
#
#         Link( name= torso
#             offset= Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.])
#             visual= Visual(offset=Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/torso/base_link.stl'})
#             collision= Collision(offset=Transform(pos=[0. 0. 0.], rot=[1. 0. 0. 0.]),
# ...
