# %% [markdown]
# # Robot INFO
#
# First, you need to install Pykin (see installations instructions). You also need a URDF file.
#
# By default, we use the files provided in the asset/urdf directory of the Pykin repo.
#
# If this directory is empty, you need to go to https://github.com/jdj2261/urdf.git and download the robot's urdf file.

# %% [markdown]
# Import the Pykin module

# %%
from pykin.robot import Robot

# %%
file_path = '../asset/urdf/baxter/baxter.urdf'

robot = Robot(file_path)
robot.show_robot_info()
# Out:
# ****************************************************************************************************
# Robot Information:
# ROBOT : iiwa14
#         OrderedDict([('iiwa_link_0',
#         Link( name= iiwa_link_0
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_0.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_0.stl'})), ('iiwa_link_1',
#         Link( name= iiwa_link_1
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_1.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_1.stl'})), ('iiwa_link_2',
#         Link( name= iiwa_link_2
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_2.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_2.stl'})), ('iiwa_link_3',
#         Link( name= iiwa_link_3
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_3.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_3.stl'})), ('iiwa_link_4',
#         Link( name= iiwa_link_4
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_4.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_4.stl'})), ('iiwa_link_5',
#         Link( name= iiwa_link_5
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_5.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_5.stl'})), ('iiwa_link_6',
#         Link( name= iiwa_link_6
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_6.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_6.stl'})), ('iiwa_link_7',
#         Link( name= iiwa_link_7
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=mesh,
#                            geom_param={'filename': 'meshes/iiwa14/visual/link_7.stl'})
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=mesh,
#                               geom_param={'filename': 'meshes/iiwa14/collision/link_7.stl'})), ('iiwa_link_ee',
#         Link( name= iiwa_link_ee
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.])
#             visual= Visual(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                            geom_type=None,
#                            geom_param=None)
#             collision= Collision(offset=Transform(rot=[1. 0. 0. 0.], pos=[0. 0. 0.]),
#                               geom_type=None,
#                               geom_param=None))])
#         OrderedDict([('iiwa_joint_1',
#         Joint( name= iiwa_joint_1
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0.     0.     0.1575])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.96705972839, 2.96705972839]), ('iiwa_joint_2',
#         Joint( name= iiwa_joint_2
#             offset= Transform(rot=[-7.31230108e-14 -7.31230108e-14  7.07106781e-01  7.07106781e-01], pos=[0.     0.     0.2025])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.09439510239, 2.09439510239]), ('iiwa_joint_3',
#         Joint( name= iiwa_joint_3
#             offset= Transform(rot=[-7.31230108e-14 -7.31230108e-14  7.07106781e-01  7.07106781e-01], pos=[0.     0.2045 0.    ])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.96705972839, 2.96705972839]), ('iiwa_joint_4',
#         Joint( name= iiwa_joint_4
#             offset= Transform(rot=[0.70710678 0.70710678 0.         0.        ], pos=[0.     0.     0.2155])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.09439510239, 2.09439510239]), ('iiwa_joint_5',
#         Joint( name= iiwa_joint_5
#             offset= Transform(rot=[-7.31230108e-14  7.31230108e-14  7.07106781e-01  7.07106781e-01], pos=[0.     0.1845 0.    ])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.96705972839, 2.96705972839]), ('iiwa_joint_6',
#         Joint( name= iiwa_joint_6
#             offset= Transform(rot=[0.70710678 0.70710678 0.         0.        ], pos=[0.     0.     0.2155])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-2.09439510239, 2.09439510239]), ('iiwa_joint_7',
#         Joint( name= iiwa_joint_7
#             offset= Transform(rot=[-7.31230108e-14  7.31230108e-14  7.07106781e-01  7.07106781e-01], pos=[0.    0.081 0.   ])
#             dtype= 'revolute'
#             axis= [0. 0. 1.]
#             limit= [-3.05432619099, 3.05432619099]), ('iiwa_joint_ee',
#         Joint( name= iiwa_joint_ee
#             offset= Transform(rot=[1. 0. 0. 0.], pos=[0.    0.    0.045])
#             dtype= 'fixed'
#             axis= None
#             limit= [None, None])])
# robot's dof : 7
# active joint names:
# ['iiwa_joint_1', 'iiwa_joint_2', 'iiwa_joint_3', 'iiwa_joint_4', 'iiwa_joint_5', 'iiwa_joint_6', 'iiwa_joint_7']
# ****************************************************************************************************

# %%
from pykin.utils import plot_utils as plt

fig, ax = plt.init_3d_figure()
plt.plot_robot(robot, 
               transformations=robot.transformations,
               ax=ax, 
               name=robot.robot_name,
               visible_visual=False, 
               visible_collision=False, 
               mesh_path='../asset/urdf/baxter/')
ax.legend()

# %%
fig, ax = plt.init_3d_figure()
plt.plot_robot(robot, 
               transformations=robot.transformations,
               ax=ax, 
               name=robot.robot_name,
               visible_visual=False, 
               visible_collision=True, 
               mesh_path='../asset/urdf/baxter/')
ax.legend()
